# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import numpy.polynomial.polynomial as poly

# %%
xf = pd.ExcelFile('sample_profiles.xlsx')
pf = sample_xf.parse('motor')
tuner_datas = ['TE12','TE7','TE6','TE5','TE14','TE8','TE4','TE16','TE15','TE10','TE3','TE2','TE1','TE18','TE32','TE28','TE27','TE19','TE31','TE29','TE26','TE23','TE20','TE30','TE25','TE22','TE21']

# %%
x_new = np.linspace(pf['Index'][0], pf['Index'][999], num=len(pf['Index'])*10)
for tuner in tuner_datas:
    coefs = poly.polyfit(pf['Index'], pf[tuner], 30)
    ffit = poly.polyval(x_new, coefs)
    plt.plot(x_new, ffit, 'r-')
    plt.plot(sample_pf['Index'],sample_pf[tuner],'b.')
    plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RankWarning: The fit may be poorly conditioned
#   This is separate from the ipykernel package so we can avoid doing imports until
